# %% [markdown]
# # Imports

# %% [markdown]
# # Incomplete Project

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# # Loading Data

# %%
observations = pd.read_csv('observations.csv')
species = pd.read_csv('species_info.csv')

# %% [markdown]
# Data Exploration

# %%
print(species.conservation_status.unique())
sns.countplot(species.conservation_status)
# Out:
# <StringArray>
# [nan, 'Species of Concern', 'Endangered', 'Threatened', 'In Recovery']
# Length: 5, dtype: str
# <Axes: xlabel='count', ylabel='conservation_status'>

# %%
print(species.category.unique())
print(species.category.value_counts())
sns.countplot(data=species, x='category', hue='conservation_status', stat='proportion')
plt.title('Grouped by Category')
plt.show()
plt.clf()
sns.countplot(data=species, x='conservation_status', hue='category', stat='proportion')
plt.title('Grouped by Conservation Status')
# df = species.groupby(['category', 'conservation_status']).scientific_name.value_counts(normalize=True).reset_index()
# sns.countplot(data=df, x='category', hue='conservation_status')
# print(df)
# Out:
# <StringArray>
# [           'Mammal',              'Bird',           'Reptile',
#          'Amphibian',              'Fish',    'Vascular Plant',
#  'Nonvascular Plant']
# Length: 7, dtype: str
# category
# Vascular Plant       4470
# Bird                  521
# Nonvascular Plant     333
# Mammal                214
# Fish                  127
# Amphibian              80
# Reptile                79
# Name: count, dtype: int64
# Text(0.5, 1.0, 'Grouped by Conservation Status')

# %% [markdown]
# # Species Freq vs Park

# %%
# sns.countplot(data=)
df = observations
# Out:
#   category                scientific_name  \
# 0   Mammal  Clethrionomys gapperi gapperi
# 1   Mammal                      Bos bison
# 2   Mammal                     Bos taurus
# 3   Mammal                     Ovis aries
# 4   Mammal                 Cervus elaphus
#
#                                         common_names conservation_status
# 0                           Gapper's Red-Backed Vole                 NaN
# 1                              American Bison, Bison                 NaN
# 2  Aurochs, Aurochs, Domestic Cattle (Feral), Dom...                 NaN
# 3  Domestic Sheep, Mouflon, Red Sheep, Sheep (Feral)                 NaN
# 4                                      Wapiti Or Elk                 NaN
